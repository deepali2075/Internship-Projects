# %%
# !pip install requests beautifulsoup4 pandas
# Out:
# Requirement already satisfied: requests in c:\users\jayesh\appdata\local\programs\python\python312\lib\site-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\jayesh\appdata\local\programs\python\python312\lib\site-packages (4.12.2)
# Requirement already satisfied: pandas in c:\users\jayesh\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jayesh\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jayesh\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jayesh\appdata\local\programs\python\python312\lib\site-packages (from requests) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jayesh\appdata\local\programs\python\python312\lib\site-packages (from requests) (2023.11.17)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jayesh\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\jayesh\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jayesh\appdata\roaming\python\python312\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jayesh\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jayesh\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\jayesh\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://books.toscrape.com/'
response = requests.get(url)
response.encoding = 'utf-8'  # Fix encoding

soup = BeautifulSoup(response.text, 'html.parser')
books = soup.find_all('article', class_='product_pod')

data = []
for book in books:
    title = book.h3.a['title']
    price_raw = book.find('p', class_='price_color').text.strip()
    price = price_raw.replace('£', '').replace('Â', '')
    availability = book.find('p', class_='instock availability').text.strip()
    rating = book.find('p', class_='star-rating')['class'][1]
    
    data.append({
        'Title': title,
        'Price (GBP)': float(price),
        'Availability': availability,
        'Rating': rating
    })

df = pd.DataFrame(data)

df.to_csv('books_data.csv', index=False)

df.style.set_properties(**{
    'background-color': '#f0f8ff',
    'color': '#000',
    'border-color': 'gray',
    'border-style': 'solid',
    'border-width': '1px',
    'text-align': 'left',
    'padding': '5px'
}).highlight_max(subset=['Price (GBP)'], color='lightgreen') \
  .highlight_min(subset=['Price (GBP)'], color='lightcoral') \
  .set_caption("📚 Book Data from books.toscrape.com")
# Out:
# <style type="text/css">
# #T_af22c_row0_col0, #T_af22c_row0_col1, #T_af22c_row0_col2, #T_af22c_row0_col3, #T_af22c_row1_col0, #T_af22c_row1_col1, #T_af22c_row1_col2, #T_af22c_row1_col3, #T_af22c_row2_col0, #T_af22c_row2_col1, #T_af22c_row2_col2, #T_af22c_row2_col3, #T_af22c_row3_col0, #T_af22c_row3_col1, #T_af22c_row3_col2, #T_af22c_row3_col3, #T_af22c_row4_col0, #T_af22c_row4_col1, #T_af22c_row4_col2, #T_af22c_row4_col3, #T_af22c_row5_col0, #T_af22c_row5_col1, #T_af22c_row5_col2, #T_af22c_row5_col3, #T_af22c_row6_col0, #T_af22c_row6_col1, #T_af22c_row6_col2, #T_af22c_row6_col3, #T_af22c_row7_col0, #T_af22c_row7_col1, #T_af22c_row7_col2, #T_af22c_row7_col3, #T_af22c_row8_col0, #T_af22c_row8_col1, #T_af22c_row8_col2, #T_af22c_row8_col3, #T_af22c_row9_col0, #T_af22c_row9_col1, #T_af22c_row9_col2, #T_af22c_row9_col3, #T_af22c_row10_col0, #T_af22c_row10_col2, #T_af22c_row10_col3, #T_af22c_row11_col0, #T_af22c_row11_col1, #T_af22c_row11_col2, #T_af22c_row11_col3, #T_af22c_row12_col0, #T_af22c_row12_col1, #T_af22c_row12_col2, #T_af22c_row12_col3, #T_af22c_row13_col0, #T_af22c_row13_col1, #T_af22c_row13_col2, #T_af22c_row13_col3, #T_af22c_row14_col0, #T_af22c_row14_col1, #T_af22c_row14_col2, #T_af22c_row14_col3, #T_af22c_row15_col0, #T_af22c_row15_col2, #T_af22c_row15_col3, #T_af22c_row16_col0, #T_af22c_row16_col1, #T_af22c_row16_col2, #T_af22c_row16_col3, #T_af22c_row17_col0, #T_af22c_row17_col1, #T_af22c_row17_col2, #T_af22c_row17_col3, #T_af22c_row18_col0, #T_af22c_row18_col1, #T_af22c_row18_col2, #T_af22c_row18_col3, #T_af22c_row19_col0, #T_af22c_row19_col1, #T_af22c_row19_col2, #T_af22c_row19_col3 {
#   background-color: #f0f8ff;
#   color: #000;
#   border-color: gray;
#   border-style: solid;
#   border-width: 1px;
#   text-align: left;
#   padding: 5px;
# }
# #T_af22c_row10_col1 {
#   background-color: #f0f8ff;
#   color: #000;
#   border-color: gray;
#   border-style: solid;
#   border-width: 1px;
#   text-align: left;
#   padding: 5px;
#   background-color: lightcoral;
# }
# #T_af22c_row15_col1 {
#   background-color: #f0f8ff;
#   color: #000;
#   border-color: gray;
#   border-style: solid;
#   border-width: 1px;
#   text-align: left;
#   padding: 5px;
#   background-color: lightgreen;
# }
# </style>
# <table id="T_af22c">
#   <caption>📚 Book Data from books.toscrape.com</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af22c_level0_col0" class="col_heading level0 col0" >Title</th>
#       <th id="T_af22c_level0_col1" class="col_heading level0 col1" >Price (GBP)</th>
#       <th id="T_af22c_level0_col2" class="col_heading level0 col2" >Availability</th>
#       <th id="T_af22c_level0_col3" class="col_heading level0 col3" >Rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af22c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_af22c_row0_col0" class="data row0 col0" >A Light in the Attic</td>
#       <td id="T_af22c_row0_col1" class="data row0 col1" >51.770000</td>
#       <td id="T_af22c_row0_col2" class="data row0 col2" >In stock</td>
#       <td id="T_af22c_row0_col3" class="data row0 col3" >Three</td>
#     </tr>
#     <tr>
#       <th id="T_af22c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_af22c_row1_col0" class="data row1 col0" >Tipping the Velvet</td>
#       <td id="T_af22c_row1_col1" class="data row1 col1" >53.740000</td>
#       <td id="T_af22c_row1_col2" class="data row1 col2" >In stock</td>
#       <td id="T_af22c_row1_col3" class="data row1 col3" >One</td>
#     </tr>
#     <tr>
#       <th id="T_af22c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_af22c_row2_col0" class="data row2 col0" >Soumission</td>
#       <td id="T_af22c_row2_col1" class="data row2 col1" >50.100000</td>
#       <td id="T_af22c_row2_col2" class="data row2 col2" >In stock</td>
#       <td id="T_af22c_row2_col3" class="data row2 col3" >One</td>
#     </tr>
#     <tr>
#       <th id="T_af22c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_af22c_row3_col0" class="data row3 col0" >Sharp Objects</td>
#       <td id="T_af22c_row3_col1" class="data row3 col1" >47.820000</td>
#       <td id="T_af22c_row3_col2" class="data row3 col2" >In stock</td>
#       <td id="T_af22c_row3_col3" class="data row3 col3" >Four</td>
#     </tr>
#     <tr>
#       <th id="T_af22c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_af22c_row4_col0" class="data row4 col0" >Sapiens: A Brief History of Humankind</td>
#       <td id="T_af22c_row4_col1" class="data row4 col1" >54.230000</td>
#       <td id="T_af22c_row4_col2" class="data row4 col2" >In stock</td>
#       <td id="T_af22c_row4_col3" class="data row4 col3" >Five</td>
#     </tr>
#     <tr>
#       <th id="T_af22c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_af22c_row5_col0" class="data row5 col0" >The Requiem Red</td>
#       <td id="T_af22c_row5_col1" class="data row5 col1" >22.650000</td>
#       <td id="T_af22c_row5_col2" class="data row5 col2" >In stock</td>
#       <td id="T_af22c_row5_col3" class="data row5 col3" >One</td>
#     </tr>
#     <tr>
#       <th id="T_af22c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_af22c_row6_col0" class="data row6 col0" >The Dirty Little Secrets of Getting Your Dream Job</td>
#       <td id="T_af22c_row6_col1" class="data row6 col1" >33.340000</td>
#       <td id="T_af22c_row6_col2" class="data row6 col2" >In stock</td>
#       <td id="T_af22c_row6_col3" class="data row6 col3" >Four</td>
#     </tr>
#     <tr>
#       <th id="T_af22c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_af22c_row7_col0" class="data row7 col0" >The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull</td>
#       <td id="T_af22c_row7_col1" class="data row7 col1" >17.930000</td>
#       <td id="T_af22c_row7_col2" class="data row7 col2" >In stock</td>
#       <td id="T_af22c_row7_col3" class="data row7 col3" >Three</td>
#     </tr>
#     <tr>
#       <th id="T_af22c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_af22c_row8_col0" class="data row8 col0" >The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics</td>
#       <td id="T_af22c_row8_col1" class="data row8 col1" >22.600000</td>
#       <td id="T_af22c_row8_col2" class="data row8 col2" >In stock</td>
#       <td id="T_af22c_row8_col3" class="data row8 col3" >Four</td>
#     </tr>
#     <tr>
#       <th id="T_af22c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_af22c_row9_col0" class="data row9 col0" >The Black Maria</td>
#       <td id="T_af22c_row9_col1" class="data row9 col1" >52.150000</td>
#       <td id="T_af22c_row9_col2" class="data row9 col2" >In stock</td>
#       <td id="T_af22c_row9_col3" class="data row9 col3" >One</td>
#     </tr>
#     <tr>
#       <th id="T_af22c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_af22c_row10_col0" class="data row10 col0" >Starving Hearts (Triangular Trade Trilogy, #1)</td>
#       <td id="T_af22c_row10_col1" class="data row10 col1" >13.990000</td>
#       <td id="T_af22c_row10_col2" class="data row10 col2" >In stock</td>
#       <td id="T_af22c_row10_col3" class="data row10 col3" >Two</td>
#     </tr>
#     <tr>
#       <th id="T_af22c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_af22c_row11_col0" class="data row11 col0" >Shakespeare's Sonnets</td>
#       <td id="T_af22c_row11_col1" class="data row11 col1" >20.660000</td>
#       <td id="T_af22c_row11_col2" class="data row11 col2" >In stock</td>
#       <td id="T_af22c_row11_col3" class="data row11 col3" >Four</td>
#     </tr>
#     <tr>
#       <th id="T_af22c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_af22c_row12_col0" class="data row12 col0" >Set Me Free</td>
#       <td id="T_af22c_row12_col1" class="data row12 col1" >17.460000</td>
#       <td id="T_af22c_row12_col2" class="data row12 col2" >In stock</td>
#       <td id="T_af22c_row12_col3" class="data row12 col3" >Five</td>
#     </tr>
#     <tr>
#       <th id="T_af22c_level0_row13" class="row_heading level0 row13
